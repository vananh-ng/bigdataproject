# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_dir = "app/data"
albums_data = pd.read_csv(f'{data_dir}/spotify_albums.csv')
artist_data = pd.read_csv(f'{data_dir}/spotify_artists.csv')
track_data = pd.read_csv(f'{data_dir}/spotify_tracks.csv')

# %%
# !pip install spotipy

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# setup client credentials
client_credentials_manager = SpotifyClientCredentials(client_id="50ef00e28b524899a40a0f2ac0410163", client_secret= "ee53b28701b746138f1f7cea7cb6851a")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Extraction

# %%
album1 = []
results = sp.search(q='year:2023', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    album1.append(album)

df_23 = pd.DataFrame(album1)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'year:2023', 'limit': 50, 'offset': 0, 'type': 'album', 'market': None} returned 404 due to Not found.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
# Get the tracks of the album
album_data_23 = []
results = sp.search(q='year:2023', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    # Get the tracks of the album
    album_tracks = sp.album_tracks(album['id'])
    for track in album_tracks['items']:
        # Append track ID, track name, album name, and release date
        album_data_23.append({
            'track_id': track['id'],
            'track_name_prev': track['name'],
            'album_name': album['name'],
            'release_date': album['release_date']
        })

track_23 = pd.DataFrame(album_data_23)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'year:2023', 'limit': 50, 'offset': 0, 'type': 'album', 'market': None} returned 404 due to Not found.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
joined_df = df_23.merge(track_23, left_on='name', right_on='album_name', how='inner')
joined_df.to_csv('df_23.csv', index=False)

# %%
album_data_20 = []
results = sp.search(q='year:2020', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    album_data_20.append(album)

df_20 = pd.DataFrame(album_data_20)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'year:2020', 'limit': 50, 'offset': 0, 'type': 'album', 'market': None} returned 404 due to Not found.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
# Get the tracks of the album
album_data_20 = []
results = sp.search(q='year:2020', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    # Get the tracks of the album
    album_tracks = sp.album_tracks(album['id'])
    for track in album_tracks['items']:
        # Append track ID, track name, album name, and release date
        album_data_20.append({
            'track_id': track['id'],
            'track_name_prev': track['name'],
            'album_name': album['name'],
            'release_date': album['release_date']
        })

track_20 = pd.DataFrame(album_data_20)

# %%
joined_df_20 = df_20.merge(track_20, left_on='name', right_on='album_name', how='inner')
joined_df_20.to_csv('df_21.csv', index=False)

# %%
album_data_21 = []
results = sp.search(q='year:2021', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    album_data_21.append(album)

df_21 = pd.DataFrame(album_data_21)

# %%
# Get the tracks of the album
album_data_21 = []
results = sp.search(q='year:2021', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    # Get the tracks of the album
    album_tracks = sp.album_tracks(album['id'])
    for track in album_tracks['items']:
        # Append track ID, track name, album name, and release date
        album_data_21.append({
            'track_id': track['id'],
            'track_name_prev': track['name'],
            'name': album['name'],
            'release_date': album['release_date'],
        })

track_21 = pd.DataFrame(album_data_21)

# %%
joined_df_21 = df_21.merge(track_21, left_on='name', right_on='album_name', how='inner')
joined_df_21.to_csv('df_21.csv', index=False)

# %%
album_data_22 = []
results = sp.search(q='year:2022', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    album_data_22.append(album)

df_22 = pd.DataFrame(album_data_22)

# %%
# Get the tracks of the album
album_data_ = []
results = sp.search(q='year:2022', type='album', limit=50)

# Print the names of the albums and their release dates
for album in results['albums']['items']:
    # Get the tracks of the album
    album_tracks = sp.album_tracks(album['id'])
    for track in album_tracks['items']:
        # Append track ID, track name, album name, and release date
        album_data_.append({
            'track_id': track['id'],
            'track_name_prev': track['name'],
            'album_name': album['name'],
            'release_date': album['release_date']
        })

track_22 = pd.DataFrame(album_data_)

# %%
joined_df_22 = df_22.merge(track_22, left_on='name', right_on='album_name', how='inner')
joined_df_22.to_csv('df_22.csv', index=False)

# %%
# get joined_df, joined_df_20, joined_df_21, joined_df_22, joined_df_23 from data folder
joined_df = pd.read_csv('df_23.csv')
joined_df_20 = pd.read_csv('df_20.csv')
joined_df_21 = pd.read_csv('df_21.csv')
joined_df_22 = pd.read_csv('df_22.csv')

# %%
album_track = [joined_df_22, joined_df_21, joined_df_20, joined_df]
merged_df = pd.concat(album_track)
merged_df = merged_df.drop(['release_date_y', 'album_name', 'release_date'], axis=1)
merged_df
# Out:
#     album_type                                            artists  \
# 0        album  [{'external_urls': {'spotify': 'https://open.s...
# 1        album  [{'external_urls': {'spotify': 'https://open.s...
# 2        album  [{'external_urls': {'spotify': 'https://open.s...
# 3        album  [{'external_urls': {'spotify': 'https://open.s...
# 4        album  [{'external_urls': {'spotify': 'https://open.s...
# ..         ...                                                ...
# 548      album  [{'external_urls': {'spotify': 'https://open.s...
# 549     single  [{'external_urls': {'spotify': 'https://open.s...
# 550     single  [{'external_urls': {'spotify': 'https://open.s...
# 551     single  [{'external_urls': {'spotify': 'https://open.s...
# 552     single  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  \
# 0    ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 1    ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# ...

# %%
merged_df = merged_df.rename(columns={'release_date_x': 'release_date'})

column_order = ['album_type', 'artists', 'available_markets', 'external_urls', 'href',
                'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks',
                'track_id', 'track_name_prev', 'uri', 'type']

# Reorder the columns of the merged DataFrame
merged_df = merged_df.reindex(columns=column_order)

# %%
merged_df.head()
# Out:
#   album_type                                            artists  \
# 0      album  [{'external_urls': {'spotify': 'https://open.s...
# 1      album  [{'external_urls': {'spotify': 'https://open.s...
# 2      album  [{'external_urls': {'spotify': 'https://open.s...
# 3      album  [{'external_urls': {'spotify': 'https://open.s...
# 4      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 1  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 2  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 3  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
# 4  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/07...
# 1  {'spotify': 'https://open.spotify.com/album/07...
# 2  {'spotify': 'https://open.spotify.com/album/07...
# ...

# %%
from concurrent.futures import ThreadPoolExecutor
# Function to get artist id from track id
def get_artist_id(track_id):
    track_info = sp.track(track_id)
    if len(track_info['artists']) > 0:
        artist_id = track_info['artists'][0]['id']
        return artist_id
    else:
        return None

# Remove NaN values from track_id column
merged_df = merged_df.dropna(subset=['track_id'])

# Create a ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=20) as executor:
    # Apply the get_artist_id function to retrieve artist_id for each track_id
    merged_df['artist_id'] = list(executor.map(get_artist_id, merged_df['track_id']))

# %%
def get_artist_ids(df):
    df = df.dropna(subset=['track_id'])

    chunks = np.array_split(df['track_id'], len(df) // 50 + 1)

    artist_ids = [None] * len(df)

    for chunk in chunks:
        tracks_info = sp.tracks(chunk.tolist())
        
        for track_info in tracks_info['tracks']:
            index = df.index[df['track_id'] == track_info['id']][0]
            artist_ids[index] = track_info['artists'][0]['id'] if len(track_info['artists']) > 0 else None

    return artist_ids

merged_df['artist_id'] = get_artist_ids(merged_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 17
#      13             artist_ids[index] = track_info['artists'][0]['id'] if len(track_info['artists']) > 0 else None
#      15     return artist_ids
# ---> 17 merged_df['artist_id'] = get_artist_ids(merged_df)
#
# Cell In[75], line 9, in get_artist_ids(df)
#       6 artist_ids = [None] * len(df)
#       8 for chunk in chunks:
# ----> 9     tracks_info = sp.tracks(chunk.tolist())
#      11     for track_info in tracks_info['tracks']:
#      12         index = df.index[df['track_id'] == track_info['id']][0]
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:382, in Spotify.tracks(self, tracks, market)
#     374 """ returns a list of tracks given a list of track IDs, URIs, or URLs
#     375
#     376     Parameters:
# ...

# %%
'''
def extract_artist_ids(df):

    # Initialize artist_ids list
    artist_ids = []

    # Split the dataframe into chunks of 50 tracks
    chunks = np.array_split(df['track_id'], len(df) // 50 + 1)

    for chunk in chunks:
        tracks_info = sp.tracks(chunk.tolist())
        
        for track_info in tracks_info['tracks']:
            artist_id = track_info['artists'][0]['id']
            artist_ids.append(artist_id)

    # Return the artist_ids list
    return artist_ids

merged_df = merged_df.dropna(subset=['track_id'])

# Now apply the function
merged_df['artist_id'] = merged_df['track_id'].apply(get_artist_id)
'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 22
#      19 merged_df = merged_df.dropna(subset=['track_id'])
#      21 # Now apply the function
# ---> 22 merged_df['artist_id'] = merged_df['track_id'].apply(get_artist_id)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
# ...

# %%
column_order = ['album_type', 'artist_id', 'available_markets', 'external_urls', 'href',
                'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks',
                'track_id', 'track_name_prev', 'uri', 'type', 'artists']
merged_df = merged_df.reindex(columns=column_order)
merged_df = merged_df.drop(['artists'], axis=1)

# %%
def get_audio_features(track_ids):
    audio_features = sp.audio_features(track_ids)
    return audio_features
audio_features = df1['track_id'].apply(get_audio_features)
audio_features= pd.DataFrame(audio_features)

# %%
df1 = pd.read_csv('df1.csv')

# %%
artist_1 = pd.read_csv('/Users/I576810/Documents/GitHub/bigdataproject/artist_data (2).csv')
artist_2 = pd.read_csv('app/data/SpotGenTrack/Data_Sources/spotify_artists.csv')
# concat artist_1 and artist_data
artist_data = pd.concat([artist_1, artist_2], axis=0)

# %%
track_1 = pd.read_csv('/Users/I576810/Documents/GitHub/bigdataproject/audio_features (2).csv')
# Define the new order of the columns
column_order = ['Unnamed: 0', 'acousticness', 'album_id', 'analysis_url', 'artists_id',
       'available_markets', 'country', 'danceability', 'disc_number',
       'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key',
       'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist',
       'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature',
       'track_href', 'track_name_prev', 'track_number', 'uri', 'valence',
       'type']

# Add any columns that are missing and fill them with NaN
for col in column_order:
    if col not in track_1.columns:
        track_1[col] = np.nan

# Reorder the columns
track_1 = track_1[column_order]

# %%
track_1['album_id'] = df1['id']
track_1['artists_id'] = artist_1['id']

# %%
# concat track_1 and spotify tracks
track_2 = pd.read_csv('app/data/SpotGenTrack/Data_Sources/spotify_tracks.csv')
track_data = pd.concat([track_1, track_2], axis=0)

# %%
track_data
# drop duplicates
track_data = track_data.drop_duplicates(subset=['id'])

# %% [markdown]
# ## Original Code

# %% [markdown]
# ### Album

# %%
albums_data = pd.read_csv('merged_df_2.csv')

# %%
display(albums_data.head())
albums_data.columns
# Out:
#    Unnamed: 0 album_type               artist_id  \
# 0           0     single  3DiDSECUqqY1AuBP8qtaIa
# 1           1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2           2     single  5YjfNaHq05WrwldRe1QSBc
# 3           3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4           4     single  2dwM9OcE4c3Ph1UBINSodx
#
#                                    available_markets  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1g...
# 1  {'spotify': 'https://open.spotify.com/album/4K...
# 2  {'spotify': 'https://open.spotify.com/album/7n...
# 3  {'spotify': 'https://open.spotify.com/album/6p...
# 4  {'spotify': 'https://open.spotify.com/album/1X...
#
# ...

# %%
# Sort albums_data release_date column
albums_data = albums_data.sort_values(by=['release_date'], ascending=False)
albums_data = albums_data.reset_index(drop=True)

# %% [markdown]
# ### Artist

# %%
artist1 = pd.read_csv('/Users/I576810/Documents/GitHub/bigdataproject/app/data/SpotGenTrack/Data_Sources/spotify_artists.csv')
artist2 = pd.read_csv('/Users/I576810/Documents/GitHub/bigdataproject/artist_data (2).csv')
artist_data = pd.concat([artist1, artist2], axis=0)

# %%
# drop duplicates
artist_data = artist_data.drop_duplicates(subset=['track_id'])
# save to csv
artist_data.to_csv('artist_data.csv', index=False)

# %%
artist_data
# Out:
#        Unnamed: 0  artist_popularity  followers  \
# 0             NaN                 89        NaN
# 3             NaN                 89        NaN
# 6             NaN                 89        NaN
# 9             NaN                 89        NaN
# 12            NaN                 89        NaN
# ...           ...                ...        ...
# 56124     56124.0                 23     1212.0
# 56125     56125.0                 42    57973.0
# 56126     56126.0                 38    20870.0
# 56127     56127.0                 44    33923.0
# 56128     56128.0                 44    42026.0
#
#                                                   genres  \
# 0                                  ['pop', 'r&b', 'rap']
# 3                                  ['pop', 'r&b', 'rap']
# 6                                  ['pop', 'r&b', 'rap']
# 9                                  ['pop', 'r&b', 'rap']
# 12                                 ['pop', 'r&b', 'rap']
# ...

# %%
display(artist_data.head())
artist_data.columns
# Out:
#    Unnamed: 0  artist_popularity  followers  \
# 0         0.0                 44    23230.0
# 1         1.0                 22      313.0
# 2         2.0                 26     1596.0
# 3         3.0                 31      149.0
# 4         4.0                 21       11.0
#
#                                               genres                      id  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1                                                 []  1dLnVku4VQUOLswwDFvRc9
# 2                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 3                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
# 4                                 ['french baroque']  4agVy03qW8juSysCTUOuDI
#
#                   name                track_id track_name_prev    type
# 0        Juliano Cezar  0wmDmAILuW9e2aRttkl4aC         track_9  artist
# 1       The Grenadines  4wqwj0gA8qPZKLl5WVqXml        track_30  artist
# ...

# %% [markdown]
# ### Track

# %%
display(track_data.head())
track_data.columns
# Out:
#      Unnamed: 0  acousticness                album_id  \
# 0           NaN        0.6690  07w0rG5TETcyihsEIZR3qG
# 276         NaN        0.2940  3RQQmkQEvNCY4prGKE6oc5
# 598         NaN        0.1430  5gCcb5fsSb6w5K8SyJrgtB
# 612         NaN        0.0533  5MS3MvWHJ3lOZPLiMxzOU6
# 617         NaN        0.2580  5r36AJ6VOJtp00oxSkBZ5h
#
#                                           analysis_url  \
# 0    https://api.spotify.com/v1/audio-analysis/5xMw...
# 276  https://api.spotify.com/v1/audio-analysis/6Xom...
# 598  https://api.spotify.com/v1/audio-analysis/7ro0...
# 612  https://api.spotify.com/v1/audio-analysis/1MTX...
# 617  https://api.spotify.com/v1/audio-analysis/5LYM...
#
#                  artists_id available_markets country  danceability  \
# 0    7tYKF4w9nC0nq9CsPZTHyP               NaN     NaN         0.507
# 276  4q3ewBCX7sLwd24euuV69X               NaN     NaN         0.804
# 598  4q3ewBCX7sLwd24euuV69X               NaN     NaN         0.652
# ...

# %% [markdown]
# ## Test

# %%
artist_data.rename(columns={'id': 'artists_id', 'name': 'artists_name'}, inplace=True)
albums_data.rename(columns={'id': 'album_id', 'release_date': 'release_date'}, inplace=True)
# Out:
# /var/folders/28/slwfq57x17xdp_m7yf64tfn40000gn/T/ipykernel_39074/451054029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artist_data.rename(columns={'id': 'artists_id', 'name': 'artists_name'}, inplace=True)

# %%
track_data = track_data.drop_duplicates(subset='album_id', keep='first')

# %%
track_data[track_data['album_id'] == '0rqRGFgE4o8kf6VM18jakx']
# Out:
#       Unnamed: 0  acousticness                album_id  \
# 5168         NaN        0.0198  0rqRGFgE4o8kf6VM18jakx
#
#                                            analysis_url  \
# 5168  https://api.spotify.com/v1/audio-analysis/7oCD...
#
#                   artists_id available_markets country  danceability  \
# 5168  4Gso3d4CscCijv0lmajZWs               NaN     NaN         0.699
#
#       disc_number  duration_ms  ...  preview_url speechiness    tempo  \
# 5168          NaN     234693.0  ...          NaN      0.0587  109.066
#
#       time_signature                                         track_href  \
# 5168             4.0  https://api.spotify.com/v1/tracks/7oCDrbTzYvxK...
#
#       track_name_prev  track_number                                   uri  \
# 5168              NaN           NaN  spotify:track:7oCDrbTzYvxKFeHaMEtKhK
#
#       valence            type
# 5168    0.285  audio_features
#
# [1 rows x 32 columns]

# %%
def merge_datasets(track_data, album_data, artist_data):
    # Renaming the columns
    artist_data.rename(columns={'id': 'artists_id', 'name': 'artists_name'}, inplace=True)
    album_data.rename(columns={'id': 'album_id', 'release_date': 'release_date'}, inplace=True)

    # Merging track_data and album_data on 'album_id'
    merged_df = pd.merge(track_data, album_data[['album_id', 'release_date']], on='album_id')

    # Merging merged_df and artist_data on 'artists_id'
    merged_df = pd.merge(merged_df, artist_data[['artists_id', 'artists_name', 'genres']], on='artists_id')

    # Extracting the release year from release_date
    merged_df['release_year'] = pd.to_datetime(merged_df['release_date']).dt.year

    # Selecting the columns you want
    merged_df = merged_df[['artists_id', 'acousticness', 'danceability', 'disc_number',
       'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key',
       'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist',
       'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature',
       'track_href', 'uri', 'valence', 'release_date', 'artists_name',
       'genres', 'release_year']]
    
    return merged_df
final_df = merge_datasets(track_data, albums_data, artist_data)
# Out:
# /var/folders/28/slwfq57x17xdp_m7yf64tfn40000gn/T/ipykernel_39074/35730744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artist_data.rename(columns={'id': 'artists_id', 'name': 'artists_name'}, inplace=True)

# %%
final_df['artists_id'] = final_df['artists_id'].str.strip("[]").str.replace("'", "")

# %%
# drop duplicates
final_df = final_df.drop_duplicates(subset=['id'])

# %%
final_df
# Out:
#                     artists_id  acousticness  danceability  disc_number  \
# 0       7tYKF4w9nC0nq9CsPZTHyP        0.6690         0.507          NaN
# 6486    4q3ewBCX7sLwd24euuV69X        0.2940         0.804          NaN
# 14214   4q3ewBCX7sLwd24euuV69X        0.1430         0.652          NaN
# 14550   1URnnhqYAYcrqrcwql10ft        0.0533         0.475          NaN
# 14560   6KImCVD70vtIoJWnq6nGn3        0.2580         0.720          NaN
# ...                        ...           ...           ...          ...
# 139093  63yrD80RY3RNEM2YDpUpO8        0.1050         0.362          NaN
# 139573  2dIgFjalVxs4ThymZ67YCE        0.2260         0.593          NaN
# 140041  5XJDexmWFLWOkjOEjOVX3e        0.1790         0.614          NaN
# 141067  3SmyWs7ou3udD8gtM0Z6Vx        0.1750         0.862          NaN
# 141073  7gOdHgIoIKoe4i9Tta6qdD        0.0389         0.644          NaN
#
#         duration_ms  energy href                      id  instrumentalness  \
# ...

# %%
final_df.sort_values(by=['release_year'], ascending=False)
# Out:
#                     artists_id  acousticness  danceability  disc_number  \
# 141073  7gOdHgIoIKoe4i9Tta6qdD       0.03890         0.644          NaN
# 50183   4oUHIQIBe0LHzYfvXNW4QM       0.45900         0.517          NaN
# 58404   4V8LLVI7PbaPR0K2TGSxFF       0.31400         0.467          NaN
# 80718   6eUKZXaKkcviH0Ku9w2n3V       0.75800         0.470          NaN
# 104372  1mcTU81TzQhprhouKaTkpq       0.00268         0.734          NaN
# ...                        ...           ...           ...          ...
# 107252  6s22t5Y3prQHyaHWUN1R1C       0.26200         0.427          NaN
# 109800  7jVv8c5Fj3E9VhNjxT4snq       0.29300         0.593          NaN
# 110280  0du5cEVh5yTK9QJze8zA0C       0.09700         0.696          NaN
# 111680  4dpARuHxo51G3z768sgnrY       0.79800         0.387          NaN
# 66708   07YUOmWljBTXwIseAUd9TW       0.76100         0.423          NaN
#
#         duration_ms  energy href                      id  instrumentalness  \
# ...

# %%
genres_to_include = genres = ['dance pop', 'electronic', 'electropop', 'hip hop', 'jazz', 'k-pop', 'latin', 'pop', 'pop rap', 'r&b', 'rock']

def get_filtered_track_df(df, genres_to_include):
    df['genres'] = df.genres.apply(lambda x: [i[1:-1] for i in str(x)[1:-1].split(", ")])
    df_exploded = df.explode("genres")[df.explode("genres")["genres"].isin(genres_to_include)]
    df_exploded.loc[df_exploded["genres"]=="korean pop", "genres"] = "k-pop"
    df_exploded_indices = list(df_exploded.index.unique())
    df = df[df.index.isin(df_exploded_indices)]
    df = df.reset_index(drop=True)
    return df

filtered_track_df_test = get_filtered_track_df(final_df, genres_to_include)
# Out:
# /var/folders/28/slwfq57x17xdp_m7yf64tfn40000gn/T/ipykernel_39074/2761673401.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df.genres.apply(lambda x: [i[1:-1] for i in str(x)[1:-1].split(", ")])

# %%
filtered_track_df_test = filtered_track_df_test.sort_values(by=['release_year'], ascending=False)

# %%
filtered_track_df_test
# Out:
#                 artists_id  acousticness  danceability  disc_number  \
# 26  7gOdHgIoIKoe4i9Tta6qdD        0.0389         0.644          NaN
# 12  4V8LLVI7PbaPR0K2TGSxFF        0.3140         0.467          NaN
# 25  2dIgFjalVxs4ThymZ67YCE        0.2260         0.593          NaN
# 24  63yrD80RY3RNEM2YDpUpO8        0.1050         0.362          NaN
# 23  63yrD80RY3RNEM2YDpUpO8        0.1050         0.362          NaN
# 22  5YGY8feqx7naU7z4HrwZM6        0.0632         0.707          NaN
# 21  5YGY8feqx7naU7z4HrwZM6        0.0632         0.707          NaN
# 20  3hcs9uc56yIGFCSy9leWe7        0.1500         0.829          NaN
# 8   2LIk90788K0zvyj2JJVwkJ        0.5070         0.807          NaN
# 19  3hcs9uc56yIGFCSy9leWe7        0.4090         0.655          NaN
# 15  6eUKZXaKkcviH0Ku9w2n3V        0.7580         0.470          NaN
# 1   1URnnhqYAYcrqrcwql10ft        0.0533         0.475          NaN
# 0   7tYKF4w9nC0nq9CsPZTHyP        0.6690         0.507          NaN
# ...

# %%
filtered_track_df_test.to_csv("app/data/SpotGenTrack/Data_Sources/filtered_track_df.csv", index=False)

# %% [markdown]
# ## Get Filtered_Data

# %%
## join artist genre information and album release date with track dataset
# drop irrelevant columns
# get only tracks after 1990
def join_genre_and_date(artist_df, album_df, track_df):
    album = album_df.rename(columns={'id':"album_id"}).set_index('album_id')
    artist = artist_df.rename(columns={'id':"artists_id",'name':"artists_name"}).set_index('artists_id')
    track = track_df.set_index('album_id').join(album['release_date'], on='album_id' )
    track.artists_id = track.artists_id.apply(lambda x: x[2:-2])
    track = track.set_index('artists_id').join(artist[['artists_name','genres']], on='artists_id' )
    track.reset_index(drop=False, inplace=True)
    track['release_year'] = pd.to_datetime(track.release_date).dt.year
    track.drop(columns = ['Unnamed: 0','country','track_name_prev','track_number','type'], inplace = True)
    
    return track[track.release_year >= 1990]

# %%
def get_filtered_track_df(df, genres_to_include):
    df['genres'] = df.genres.apply(lambda x: [i[1:-1] for i in str(x)[1:-1].split(", ")])
    df_exploded = df.explode("genres")[df.explode("genres")["genres"].isin(genres_to_include)]
    df_exploded.loc[df_exploded["genres"]=="korean pop", "genres"] = "k-pop"
    df_exploded_indices = list(df_exploded.index.unique())
    df = df[df.index.isin(df_exploded_indices)]
    df = df.reset_index(drop=True)
    return df

# %%
genres_to_include = genres = ['dance pop', 'electronic', 'electropop', 'hip hop', 'jazz', 'k-pop', 'latin', 'pop', 'pop rap', 'r&b', 'rock']
track_with_year_and_genre = join_genre_and_date(artist_data, albums_data, track_data)
filtered_track_df = get_filtered_track_df(track_with_year_and_genre, genres_to_include)

# %%
filtered_track_df["uri"] = filtered_track_df["uri"].str.replace("spotify:track:", "")
filtered_track_df = filtered_track_df.drop(columns=['analysis_url', 'available_markets'])

# %%
display(filtered_track_df.head())
filtered_track_df.columns
# Out:
#                artists_id  acousticness  danceability  disc_number  \
# 0  68WwJXWrpo1yVOOIZjLSeT        0.0268         0.506          1.0
# 1  09xj0S68Y1OU1vHMCZAIvz        0.5050         0.487          1.0
# 2  6pSsE5y0uJMwYj83KrPyf9        0.1330         0.629          1.0
# 3  7slfeZO9LsJbWgpkIoXBUJ        0.4060         0.590          1.0
# 4  09hVIj6vWgoCDtT03h8ZCa        0.0316         0.727          1.0
#
#    duration_ms  energy                                               href  \
# 0     248777.0   0.741  https://api.spotify.com/v1/tracks/0UATU9OJxh4m...
# 1     171573.0   0.297  https://api.spotify.com/v1/tracks/4JH1M62gVDND...
# 2     207396.0   0.706  https://api.spotify.com/v1/tracks/0h7Ld5CvgzaU...
# 3     279000.0   0.597  https://api.spotify.com/v1/tracks/4S1bYWrLOC8s...
# 4     218773.0   0.380  https://api.spotify.com/v1/tracks/758mQT4zzlvB...
#
#                        id  instrumentalness   key  ...  speechiness    tempo  \
# ...

# %%
# sort filtered_track_df by release_year acending
filtered_track_df = filtered_track_df.sort_values(by=['release_year'], ascending=False)

# %%
filtered_track_df
# Out:
#                   artists_id  acousticness  danceability  disc_number  \
# 459   1RyvyyTE3xzB2ZywiAwp0i       0.01510         0.888          1.0
# 3653  0yN7xI1blow9nYIK0R8nM7       0.00129         0.501          1.0
# 3651  4SqTiwOEdYrNayaGMkc7ia       0.01710         0.722          1.0
# 7183  5JMLG56F1X5mFmWNmS0iAp       0.92600         0.616          1.0
# 9203  2oX42qP5ineK3hrhBECLmj       0.08750         0.641          1.0
# ...                      ...           ...           ...          ...
# 7427  2qQeKHrQJHLLbvDAOSO874       0.06610         0.363          1.0
# 1943  7wOZy3KdFVVINgNFFxkxwO       0.59200         0.733          2.0
# 3739  0EVUivUkugMtNF09L4QBMH       0.00847         0.525          1.0
# 7425  7ihLzUpuNecU5VBkvOUDNq       0.02410         0.273          1.0
# 1361  41ESHLayJ5sDKjAOv6cMhe       0.08120         0.689          1.0
#
#       duration_ms  energy                                               href  \
# ...

# %%
filtered_track_df.to_csv("app/data/SpotGenTrack/Data_Sources/filtered_track_df.csv", index=False)
