# %%
import pandas as pd
import pickle


df = pd.read_pickle('../app/data/album_and_artists.pkl')

# %%
df.head()
# Out:
#    album_type               artist_id                album_id
# 0       album  4obzFoKoKRHIphyHzJ35G3  0rqRGFgE4o8kf6VM18jakx  \
# 20     single  4obzFoKoKRHIphyHzJ35G3  4HjMn5cTiTU7LkG4GcKDjg
# 21     single  4obzFoKoKRHIphyHzJ35G3  2Zvtg0DzZ71AQsn3P5KYQC
# 22     single  4obzFoKoKRHIphyHzJ35G3  1rNj1DvnXIH5irucrzT4zo
# 23     single  4obzFoKoKRHIphyHzJ35G3  4Y6jkhla5dLnq9vfPI7gmX
#
#                                                  name  release_year
# 0   METRO BOOMIN PRESENTS SPIDER-MAN: ACROSS THE S...          2023  \
# 20                                                LBD          2019
# 21                     Por Un Amor/Cucurrucucú Paloma          2018
# 22                                     Cuando Te Besé          2018
# 23            Zooted (feat. French Montana & Farruko)          2018
#
#     total_tracks  followers                                   genres
# 0             18  4312135.0  ['latin viral pop', 'pop', 'reggaeton']  \
# ...
